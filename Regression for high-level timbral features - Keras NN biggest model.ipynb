# %%
pip install mirdata
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mirdata
#   Downloading mirdata-0.3.7-py3-none-any.whl (14.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 39.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from mirdata) (1.4.4)
# Collecting jams
#   Downloading jams-0.3.4.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 KB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: librosa>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from mirdata) (0.10.0.post2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from mirdata) (6.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.9/dist-packages (from mirdata) (1.22.4)
# Requirement already satisfied: smart-open>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from mirdata) (6.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from mirdata) (2.27.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from mirdata) (1.10.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from mirdata) (4.65.0)
# Requirement already satisfied: chardet in /usr/lib/python3/dist-packages (from mirdata) (3.0.4)
# Collecting Deprecated>=1.2.13
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.9/dist-packages (from mirdata) (3.8.0)
# Collecting pretty-midi>=0.2.8
#   Downloading pretty_midi-0.2.10.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 35.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from Deprecated>=1.2.13->mirdata) (1.15.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (3.0.0)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (1.0.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (4.5.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (1.2.2)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (1.6.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (0.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (4.4.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (1.1.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (0.12.1)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.9/dist-packages (from librosa>=0.8.0->mirdata) (0.3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->mirdata) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0.0->mirdata) (2022.7.1)
# Collecting mido>=1.1.16
#   Downloading mido-1.2.10-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 KB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from pretty-midi>=0.2.8->mirdata) (1.16.0)
# Requirement already satisfied: sortedcontainers>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from jams->mirdata) (2.4.0)
# Requirement already satisfied: jsonschema>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from jams->mirdata) (4.3.3)
# Collecting mir_eval>=0.5
#   Downloading mir_eval-0.7.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/90.7 KB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->mirdata) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->mirdata) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->mirdata) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->mirdata) (1.26.15)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0.0->jams->mirdata) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0.0->jams->mirdata) (0.19.3)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from mir_eval>=0.5->jams->mirdata) (0.18.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.51.0->librosa>=0.8.0->mirdata) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.51.0->librosa>=0.8.0->mirdata) (67.6.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from pooch<1.7,>=1.0->librosa>=0.8.0->mirdata) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from pooch<1.7,>=1.0->librosa>=0.8.0->mirdata) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.20.0->librosa>=0.8.0->mirdata) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.9/dist-packages (from soundfile>=0.12.1->librosa>=0.8.0->mirdata) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.8.0->mirdata) (2.21)
# Building wheels for collected packages: pretty-midi, jams, mir_eval
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.10-py3-none-any.whl size=5592303 sha256=fba9ae11deb562a5590f76b6893af853b9d2333f11ebbe12b779ea520d5cb061
#   Stored in directory: /root/.cache/pip/wheels/75/ec/20/b8e937a5bcf1de547ea5ce465db7de7f6761e15e6f0a01e25f
#   Building wheel for jams (setup.py) ... done
#   Created wheel for jams: filename=jams-0.3.4-py3-none-any.whl size=64923 sha256=ff86102775ff517d7c6b58d772b549b5db3dbf2c324d54c03d10e74283c27a7b
#   Stored in directory: /root/.cache/pip/wheels/3a/30/bd/89f3791651385a3a5f02865508db932f506b26304f0e428593
#   Building wheel for mir_eval (setup.py) ... done
#   Created wheel for mir_eval: filename=mir_eval-0.7-py3-none-any.whl size=100718 sha256=05a31803de2cf0883ab8503305bea8618b03d8eb360a2b665375021561ab7ca2
#   Stored in directory: /root/.cache/pip/wheels/e9/f5/d5/eb3db1d056253da195208853842bce745a84b29f44cab59b6c
# Successfully built pretty-midi jams mir_eval
# Installing collected packages: mido, pretty-midi, Deprecated, mir_eval, jams, mirdata
# Successfully installed Deprecated-1.2.13 jams-0.3.4 mido-1.2.10 mir_eval-0.7 mirdata-0.3.7 pretty-midi-0.2.10

# %%
import pandas
import os 
import pickle

import time

import mirdata
import numpy as np
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Conv1D
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import MaxPooling1D

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# GLOBAL PATHS and variables
pickleFiles_FolderName = '/content/gdrive/MyDrive/Colab Notebooks/Music Information Retrieval/Assignment/Final'

# %%
tensF_ShuffleSeed = 0
train_split = 0.8 # validation split is the same as train_split

# %%
# https://mirdata.readthedocs.io/en/stable/source/mirdata.html#module-mirdata.datasets.freesound_one_shot_percussive_sounds

percDataset = mirdata.initialize("freesound_one_shot_percussive_sounds")
percDataset.download()  
print('Finished downloading freesound_one_shot_percussive_sounds dataset.')
percDataset.validate() 
print('Finished validating freesound_one_shot_percussive_sounds dataset.')
# Out:
# 107MB [00:48, 2.33MB/s]
# 5.35MB [00:15, 356kB/s]
# 57.3MB [00:21, 2.74MB/s]
# 1.29MB [00:03, 383kB/s]
# 8.00kB [00:01, 4.15kB/s]
# Finished downloading freesound_one_shot_percussive_sounds dataset.
# 100%|██████████| 1/1 [00:00<00:00, 220.35it/s]
# 100%|██████████| 10254/10254 [00:01<00:00, 6570.38it/s]
# Finished validating freesound_one_shot_percussive_sounds dataset.

# %%
# Find min and max values of timbral synthesis features annotations, 
# so that we can normalize later
with open(os.path.join(pickleFiles_FolderName, 'audioFileWavef_TimbralFeatures_DF.p'), 'rb') as audioFileWavef_TimbralFeatures_DF_Pickle:
  audioFileWavef_TimbralFeatures_DF = pickle.load(audioFileWavef_TimbralFeatures_DF_Pickle)

audioFileWavef_TimbralFeatures_DF.head() # successfully retrieved pandas dataframe from pickle file
# Out:
#    freesound_sound_id  audio_waveform_sampleN_0  audio_waveform_sampleN_1  \
# 0              203887                 -0.000031                 -0.000031
# 1              203893                 -0.000031                 -0.000031
# 2              319613                  0.023254                 -0.362274
# 3              361958                 -0.003174                 -0.002441
# 4              277684                  0.001007                  0.001984
#
#    audio_waveform_sampleN_2  audio_waveform_sampleN_3  \
# 0                  0.000000                 -0.000031
# 1                 -0.000031                 -0.000031
# 2                 -0.115540                  0.606995
# 3                 -0.009338                 -0.005646
# 4                  0.002197                  0.002533
#
#    audio_waveform_sampleN_4  audio_waveform_sampleN_5  \
# 0                 -0.000031                 -0.000031
# 1                  0.000000                  0.000000
# 2                  0.025940                 -0.159943
# 3                 -0.014252                 -0.008392
# 4                  0.002716                  0.002594
#
#    audio_waveform_sampleN_6  audio_waveform_sampleN_7  \
# 0                  0.000000                  0.000031
# 1                  0.000000                  0.000031
# 2                  0.004211                 -0.385834
# 3                 -0.015869                  0.002869
# 4                  0.002838                  0.003174
#
#    audio_waveform_sampleN_8  ...  audio_waveform_sampleN_15997  \
# 0                  0.000031  ...                           0.0
# 1                  0.000061  ...                           0.0
# 2                  0.056091  ...                           0.0
# 3                  0.007721  ...                           0.0
# 4                  0.002899  ...                           0.0
#
#    audio_waveform_sampleN_15998  audio_waveform_sampleN_15999   hardness  \
# 0                           0.0                           0.0  58.964800
# 1                           0.0                           0.0  68.950243
# 2                           0.0                           0.0  70.543572
# 3                           0.0                           0.0  54.433781
# 4                           0.0                           0.0  71.738502
#
#        depth  brightness  roughness     warmth  sharpness  boominess
# 0  52.583343   51.286288  54.450442  53.450765  43.850985  36.458663
# 1  35.996983   71.406639  67.818761  34.422775  58.811990  21.432983
# 2  54.408973   62.367384  55.920217  39.524543  53.265036  37.984857
# 3  70.611045   38.445561  43.515676  55.998536  40.757533  43.517493
# 4  57.402842   73.531486  50.322603  36.656637  56.843763  28.371194
#
# [5 rows x 16008 columns]

# %%
timbFeat_List = ["hardness", "depth", "brightness", "roughness", "warmth", "sharpness", "boominess"]

# %%
timbFeat_MinList = audioFileWavef_TimbralFeatures_DF[timbFeat_List].min(axis = 0, numeric_only = True)
timbFeat_MaxList = audioFileWavef_TimbralFeatures_DF[timbFeat_List].max(axis = 0, numeric_only = True)

# %%
print(timbFeat_MinList)
print(timbFeat_MaxList)
# Out:
# hardness      11.586026
# depth          0.140980
# brightness    10.874446
# roughness      0.000000
# warmth         7.696248
# sharpness      0.000000
# boominess      0.000000
# dtype: float64
# hardness       82.596457
# depth         100.000000
# brightness     84.309024
# roughness      77.090665
# warmth         78.870422
# sharpness      92.585410
# boominess      71.482249
# dtype: float64

# %%
timbFeat_List = ["ac_hardness", "ac_depth", "ac_brightness", "ac_roughness", "ac_warmth", "ac_sharpness", "ac_boominess"]

# %%
# https://mirdata.readthedocs.io/en/stable/source/tutorial.html

def freeSound_PercDataset_generator():
    track_ids = percDataset.track_ids
    for track_id in track_ids:
      track = percDataset.track(track_id)
      audio_signal, _ = track.audio
      audioSignal = np.array(audio_signal)
      audioSignal.resize(16000, refcheck=False)
      # print(len(audioSignal))
      # consider training example as valid only if all annotations are present
      # (there are some missing keys in the mir_data track.audiocommons_analysis dict)
      timbFeaturesGroundTruth = []
      for index, timbFeatName in enumerate(timbFeat_List):
        # apply normalization between 0 and 1 (y = x-min(x) / max(x) - min(x))
        if timbFeatName in track.audiocommons_analysis.keys():
          normValue = (track.audiocommons_analysis[timbFeatName] - timbFeat_MinList[index]) / (timbFeat_MaxList[index] - timbFeat_MinList[index])
          timbFeaturesGroundTruth.append(np.float32(normValue))
        else:
          timbFeaturesGroundTruth.append(0.)
      # Keras' Input layer accepts either 2 different 'datasets' for x (examples) and y (ground truth),
      # or a single tuple object as (x, y)
      # https://keras.io/api/models/model_training_apis/ 
      yield (audioSignal,
              timbFeaturesGroundTruth)

dataset = tf.data.Dataset.from_generator(
    freeSound_PercDataset_generator,
    output_signature=(
         tf.TensorSpec(shape = (16000), dtype = tf.float32, name = 'audio_waveform'),
         tf.TensorSpec(shape = (7), dtype = tf.float32, name = 'annotations')))

# %%
dataset
# Out:
# <FlatMapDataset element_spec=(TensorSpec(shape=(16000,), dtype=tf.float32, name='audio_waveform'), TensorSpec(shape=(7,), dtype=tf.float32, name='annotations'))>

# %%
# check dataset 
#for element in dataset:
#  print(element)

# %%
# Shuffle entire dataset and split it into train/validation/test datasets

num_elements = len(list(dataset))
print(f'There are {num_elements} elements in the Dataset')

dataset = dataset.shuffle(num_elements, seed=tensF_ShuffleSeed)
    
train_size = int(train_split * num_elements)
test_size = int((1. - train_split) * num_elements)
    
test_ds = dataset.skip(train_size).take(test_size)

train_size_withValSplit = int(train_split * train_size)
validation_size = int((1. - train_split) * train_size)

train_ds = dataset.take(train_size_withValSplit)    
validation_ds = dataset.skip(train_size_withValSplit).take(validation_size)

print(f'There are {len(list(train_ds))} elements in the training Dataset')
print(f'There are {len(list(validation_ds))} elements in the validation Dataset')
print(f'There are {len(list(test_ds))} elements in the test Dataset')
# Out:
# There are 10254 elements in the Dataset
# There are 6562 elements in the training Dataset
# There are 1640 elements in the validation Dataset
# There are 2050 elements in the test Dataset

# %%
batch_size = 1

# %%
train_ds = train_ds.batch(batch_size)
validation_ds = validation_ds.batch(batch_size)
test_ds = test_ds.batch(batch_size)

# %%
model = Sequential()
model.add(Input(shape = (16000, 1), batch_size = batch_size))

# with stride 1, the output size == input size - filter size + 1 (16000 - 7 + 1)
model.add(Conv1D(100, 7, strides = 1, activation="relu", padding = 'valid', name = "Conv1D_1"))
model.add(MaxPooling1D(pool_size = 2, name = "MaxPooling_1D_1"))

model.add(Conv1D(50, 7, strides = 1, activation="relu", padding = 'valid', name = "Conv1D_2"))
model.add(MaxPooling1D(pool_size = 2, name = "MaxPooling_1D_2"))

model.add(Conv1D(20, 7, strides = 1, activation="relu", padding = 'valid', name = "Conv1D_3"))
model.add(MaxPooling1D(pool_size = 2, name = "MaxPooling_1D_3"))

model.add(Conv1D(10, 7, strides = 1, activation="relu", padding = 'valid', name = "Conv1D_4"))
model.add(MaxPooling1D(pool_size = 2, name = "MaxPooling_1D_4"))

model.add(Conv1D(4, 7, strides = 1, activation="relu", padding = 'valid', name = "Conv1D_5"))
model.add(MaxPooling1D(pool_size = 2, name = "MaxPooling_1D_5"))

model.add(Flatten())
model.add(Dense(1000, activation = 'relu', name = "Dense_1"))
model.add(Dense(100, activation = 'relu', name = "Dense_2"))

model.add(Dense(7, activation = 'linear', name = "Dense_3"))

# In a regression task, since the outputs and ground truth values are continuous values,
# rather than classes, and hence ezact prediction are not possible, accuracy is not used 
# https://www.freecodecamp.org/news/evaluation-metrics-for-regression-problems-machine-learning/
# https://keras.io/api/metrics/
_metrics = ['mean_absolute_error', 'mean_squared_error']
model.compile(loss = 'mean_absolute_error', loss_weights = [1/7,1/7,1/7,1/7,1/7,1/7,1/7], optimizer = 'adam', metrics = _metrics)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Conv1D_1 (Conv1D)           (1, 15994, 100)           800
#
#  MaxPooling_1D_1 (MaxPooling  (1, 7997, 100)           0
#  1D)
#
#  Conv1D_2 (Conv1D)           (1, 7991, 50)             35050
#
#  MaxPooling_1D_2 (MaxPooling  (1, 3995, 50)            0
#  1D)
#
#  Conv1D_3 (Conv1D)           (1, 3989, 20)             7020
#
#  MaxPooling_1D_3 (MaxPooling  (1, 1994, 20)            0
#  1D)
#
#  Conv1D_4 (Conv1D)           (1, 1988, 10)             1410
#
#  MaxPooling_1D_4 (MaxPooling  (1, 994, 10)             0
#  1D)
#
#  Conv1D_5 (Conv1D)           (1, 988, 4)               284
#
#  MaxPooling_1D_5 (MaxPooling  (1, 494, 4)              0
#  1D)
#
#  flatten (Flatten)           (1, 1976)                 0
#
#  Dense_1 (Dense)             (1, 1000)                 1977000
#
#  Dense_2 (Dense)             (1, 100)                  100100
#
#  Dense_3 (Dense)             (1, 7)                    707
#
# =================================================================
# Total params: 2,122,371
# Trainable params: 2,122,371
# Non-trainable params: 0
# _________________________________________________________________

# %%
pngFilePath = '/content/gdrive/MyDrive/Colab Notebooks/Music Information Retrieval/Assignment/Final/biggest_model_plot.png'
tf.keras.utils.plot_model(model, to_file = pngFilePath, show_shapes = True, show_dtype = True, show_layer_names = True, rankdir = 'LR', dpi = 96, show_layer_activations = True)

# %%
start = time.monotonic()
history = model.fit(train_ds, epochs = 20, batch_size = batch_size, validation_data = validation_ds)
stop = time.monotonic()
print(f'Finished training. It took {stop - start} seconds')
# Out:
# Epoch 1/20
# 6562/6562 [==============================] - 75s 8ms/step - loss: 0.0134 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0169 - val_loss: 0.0107 - val_mean_absolute_error: 0.0747 - val_mean_squared_error: 0.0109
# Epoch 2/20
# 6562/6562 [==============================] - 63s 9ms/step - loss: 0.0104 - mean_absolute_error: 0.0728 - mean_squared_error: 0.0104 - val_loss: 0.0112 - val_mean_absolute_error: 0.0782 - val_mean_squared_error: 0.0115
# Epoch 3/20
# 6562/6562 [==============================] - 62s 8ms/step - loss: 0.0094 - mean_absolute_error: 0.0660 - mean_squared_error: 0.0086 - val_loss: 0.0087 - val_mean_absolute_error: 0.0609 - val_mean_squared_error: 0.0076
# Epoch 4/20
# 6562/6562 [==============================] - 62s 8ms/step - loss: 0.0089 - mean_absolute_error: 0.0622 - mean_squared_error: 0.0078 - val_loss: 0.0085 - val_mean_absolute_error: 0.0595 - val_mean_squared_error: 0.0069
# Epoch 5/20
# 6562/6562 [==============================] - 62s 8ms/step - loss: 0.0085 - mean_absolute_error: 0.0595 - mean_squared_error: 0.0071 - val_loss: 0.0079 - val_mean_absolute_error: 0.0556 - val_mean_squared_error: 0.0066
# Epoch 6/20
# 6562/6562 [==============================] - 71s 10ms/step - loss: 0.0082 - mean_absolute_error: 0.0576 - mean_squared_error: 0.0068 - val_loss: 0.0084 - val_mean_absolute_error: 0.0591 - val_mean_squared_error: 0.0069
# Epoch 7/20
# 6562/6562 [==============================] - 63s 8ms/step - loss: 0.0082 - mean_absolute_error: 0.0571 - mean_squared_error: 0.0068 - val_loss: 0.0079 - val_mean_absolute_error: 0.0556 - val_mean_squared_error: 0.0062
# Epoch 8/20
# 6562/6562 [==============================] - 71s 10ms/step - loss: 0.0079 - mean_absolute_error: 0.0555 - mean_squared_error: 0.0064 - val_loss: 0.0082 - val_mean_absolute_error: 0.0577 - val_mean_squared_error: 0.0073
# Epoch 9/20
# 6562/6562 [==============================] - 62s 8ms/step - loss: 0.0079 - mean_absolute_error: 0.0553 - mean_squared_error: 0.0064 - val_loss: 0.0078 - val_mean_absolute_error: 0.0549 - val_mean_squared_error: 0.0060
# Epoch 10/20
# 6562/6562 [==============================] - 71s 10ms/step - loss: 0.0077 - mean_absolute_error: 0.0540 - mean_squared_error: 0.0061 - val_loss: 0.0078 - val_mean_absolute_error: 0.0547 - val_mean_squared_error: 0.0065
# Epoch 11/20
# 6562/6562 [==============================] - 63s 8ms/step - loss: 0.0076 - mean_absolute_error: 0.0532 - mean_squared_error: 0.0059 - val_loss: 0.0073 - val_mean_absolute_error: 0.0510 - val_mean_squared_error: 0.0054
# Epoch 12/20
# 6562/6562 [==============================] - 63s 9ms/step - loss: 0.0075 - mean_absolute_error: 0.0525 - mean_squared_error: 0.0059 - val_loss: 0.0075 - val_mean_absolute_error: 0.0523 - val_mean_squared_error: 0.0060
# Epoch 13/20
# 6562/6562 [==============================] - 63s 8ms/step - loss: 0.0074 - mean_absolute_error: 0.0520 - mean_squared_error: 0.0058 - val_loss: 0.0072 - val_mean_absolute_error: 0.0502 - val_mean_squared_error: 0.0054
# Epoch 14/20
# 6562/6562 [==============================] - 62s 8ms/step - loss: 0.0073 - mean_absolute_error: 0.0511 - mean_squared_error: 0.0055 - val_loss: 0.0069 - val_mean_absolute_error: 0.0481 - val_mean_squared_error: 0.0051
# Epoch 15/20
# 6562/6562 [==============================] - 63s 8ms/step - loss: 0.0073 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0056 - val_loss: 0.0071 - val_mean_absolute_error: 0.0500 - val_mean_squared_error: 0.0055
# Epoch 16/20
# 6562/6562 [==============================] - 62s 8ms/step - loss: 0.0072 - mean_absolute_error: 0.0505 - mean_squared_error: 0.0055 - val_loss: 0.0068 - val_mean_absolute_error: 0.0477 - val_mean_squared_error: 0.0053
# Epoch 17/20
# 6562/6562 [==============================] - 63s 8ms/step - loss: 0.0071 - mean_absolute_error: 0.0497 - mean_squared_error: 0.0054 - val_loss: 0.0066 - val_mean_absolute_error: 0.0464 - val_mean_squared_error: 0.0047
# Epoch 18/20
# 6562/6562 [==============================] - 71s 10ms/step - loss: 0.0070 - mean_absolute_error: 0.0491 - mean_squared_error: 0.0052 - val_loss: 0.0071 - val_mean_absolute_error: 0.0497 - val_mean_squared_error: 0.0052
# Epoch 19/20
# 6562/6562 [==============================] - 62s 8ms/step - loss: 0.0070 - mean_absolute_error: 0.0487 - mean_squared_error: 0.0052 - val_loss: 0.0067 - val_mean_absolute_error: 0.0472 - val_mean_squared_error: 0.0052
# Epoch 20/20
# 6562/6562 [==============================] - 71s 10ms/step - loss: 0.0070 - mean_absolute_error: 0.0487 - mean_squared_error: 0.0052 - val_loss: 0.0069 - val_mean_absolute_error: 0.0483 - val_mean_squared_error: 0.0049
# Finished training. It took 1362.20194377 seconds

# %%
model.metrics_names
# Out:
# ['loss', 'mean_absolute_error', 'mean_squared_error']

# %%
testLoss, mean_absolute_error, mean_squared_error = model.evaluate(test_ds, batch_size = batch_size)
# Out:
# 2050/2050 [==============================] - 15s 4ms/step - loss: 0.0068 - mean_absolute_error: 0.0478 - mean_squared_error: 0.0050

# %%
print(type(testLoss))

print(model.metrics_names)
print(testLoss)
print(mean_absolute_error)
print(mean_squared_error)
# Out:
# <class 'float'>
# ['loss', 'mean_absolute_error', 'mean_squared_error']
# 0.00682160584256053
# 0.04775121062994003
# 0.005005833692848682

# %%
# https://keras.io/guides/training_with_built_in_methods/

import matplotlib.pyplot as plt

def plot_loss_and_acc(history):
    train_loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    fig = plt.figure(figsize=(12,5))

    ax = fig.add_subplot(121)
    ax.plot(range(len(train_loss)), train_loss, label="Train Loss");
    plt.xlabel("Epochs"); plt.ylabel("Loss (M. A. E.)");
    plt.title("Train Loss (M. A. E.)");
    plt.legend(loc="best");

    ax = fig.add_subplot(122)
    ax.plot(range(len(val_loss)), val_loss, label="Validation loss");
    plt.xlabel("Epochs"); plt.ylabel("Validation loss (M. A. E.)");
    plt.title("Validation loss (M. A. E.)");
    plt.legend(loc="best");

plot_loss_and_acc(history)
print(f'Test loss; {testLoss}')

'''
Overfitting if: training loss << validation loss
Underfitting if: training loss >> validation loss
Just right if training loss ~ validation loss
'''
# Out:
# Test loss; 0.00682160584256053
# '\nOverfitting if: training loss << validation loss\nUnderfitting if: training loss >> validation loss\nJust right if training loss ~ validation loss\n'
